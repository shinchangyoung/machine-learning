# %% [markdown]
# <a href="https://colab.research.google.com/github/shinchangyoung/python-algorithm-solutions/blob/main/%EA%B8%B0%EA%B3%84%ED%95%99%EC%8A%B5/matplotlib2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

categories = ['A', 'B', 'C', 'D']
values = [25, 40, 30, 20]

# 막대 그래프 생성
plt.bar(categories, values, color='skyblue')
#grid함수의 true,false는 그래프에 그리드를 표시하는가에 대한 확인 여부
plt.grid(True, linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

# 각 막대 머리 위치에 텍스트 추가
for i, value in enumerate(values):
  # 옵션 추가
  plt.text(i, value + 1, str(value), ha='center', va='bottom', color='black', fontsize=10)

plt.ylim(0,45)

plt.title('Bar Chart with Text Annotations', pad = 30, color = 'r')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.show()
# Out:
# <ipython-input-9-391f189591c9>:8: UserWarning: First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#   plt.grid(False, linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

# %%
from os.path import basename
import matplotlib.pyplot as plt

barName = ['b1','b2','b3','b4']
values = [30, 20, 40, 50]


for i, value2 in enumerate(values):
 plt.text(i, value2 + 1, str(value2), ha='center', va='bottom', color='black', fontsize=10)

plt.ylim(0,55)
plt.grid(True, linestyle='--', linewidth=0.5, color='gray', alpha=0.7)
plt.bar(barName, values, color = 'g')
plt.show()
